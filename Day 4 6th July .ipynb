# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aspdi\\OneDrive\\Desktop\\Hexaware'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is B8BA-5E49
#
#  Directory of C:\Users\aspdi\OneDrive\Desktop\Hexaware
#
# 06-07-2022  18:48    <DIR>          .
# 04-07-2022  22:33    <DIR>          ..
# 06-07-2022  18:48    <DIR>          .ipynb_checkpoints
# 01-07-2022  16:02           640,351 0120_RESOURCE_AgilePrinciplesInfographic.jpg
# 02-07-2022  00:15         1,691,718 Agile and Scrum.pptx
# 06-07-2022  03:27            85,419 day 3 5th June.ipynb
# 06-07-2022  18:47                72 Day 4 6th July .ipynb
# 30-06-2022  16:35           155,794 Recap python fundamental.ipynb
# 01-07-2022  15:53            87,965 ScrumTermWorksheet.docx
# 01-07-2022  20:21            68,279 Top5AgilePrinciples.docx
# 06-07-2022  13:42    <DIR>          unit_testing
#                7 File(s)      2,729,598 bytes
#                4 Dir(s)  11,839,946,752 bytes free

# %%
open(r'test.txt','x')
# Out:
# <_io.TextIOWrapper name='test.txt' mode='x' encoding='cp1252'>

# %%
f=open(r'test.txt','w')
f.write("python file handling")
f.close()

# %%
f=open(r'test.txt','r')
print(f.read())
# Out:
# python file handling

# %%
f=open(r'test.txt','w')
f.write("machine learning and bigdata analytics using apache hadoop, spark and aws")
f.close()

# %%
f=open(r'test.txt','a')
f.write("AWS iot core service used to impliment iot")
f.close()

# %%
f=open(r'test.txt','a')
f.write("\n AWS iot core service used to impliment iot")
f.close()

# %%
f=open(r'test.txt','r')
print(f.read())
# Out:
# machine learning and bigdata analytics using apache hadoop, spark and awsAWS iot core service used to impliment iot
#  AWS iot core service used to impliment iot

# %%
import requests

# %%
r=requests.get('https://google.com')

# %%
r.content
f=open(r'res.txt','w')
f.write(str(r.content))
f.close()

# %%
f=open(r'google.html','w')
f.write(r.text)
f.close()

# %%
#generator 

def square(n):
    for i in range(n):
        return i**2

# %%
out=square(5)

# %%
type(out)
# Out:
# int

# %%
def square(n):
    for i in range(n):
        yield i**2

# %%
out=square(5)

# %%
type(out)
# Out:
# generator

# %%
for i in out:
    print(i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
a=iter([78,89,225,56,4,8,56])

# %%
next(a)
# Out:
# 78

# %%
out
# Out:
# <generator object square at 0x000001DE53F59350>

# %% [raw]
# python unit testing

# %% [raw]
# Robot
# Pytest
# unitest
# DocTest
# Testify

# %%
#!pip3 install pytest

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aspdi\\OneDrive\\Desktop\\Hexaware'

# %%
os.chdir(r'C:\Users\aspdi\OneDrive\Desktop\Hexaware\testing')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aspdi\\OneDrive\\Desktop\\Hexaware\\testing'

# %%
# %%writefile mathfile.py


def add(a,b):
    return a+b

def sub(a,b):
    return a-b
    
def multiply(a,b):
    return a*b
# Out:
# Overwriting mathfile.py

# %%
# %%writefile tst_mathfile.py

import mathfile

def test_add():
    output=mathfile.add(2,3)
    assert output==5

def test_add_sub():
    output=mathfile.sub(4,3)
    assert output==1

def test_multiply():
    output=mathfile.multiply(2,3)
    assert output==6
# Out:
# Overwriting tst_mathfile.py

# %% [raw]
# pytest tst_mathfile.py
# pytest -v
# pytest -v test_mathfile.py
# pytest test_mathfile.py::test_add
# pytest test_mathfile.py::test_add -v
# pytest test_mathfile.py -v -k "add"

# %% [raw]
# write a simple python code to calculate the area and perimeter of reactangle and perform unit testing using pytest.

# %%
# %%writefile test_mathfile1.py

import mathfile
import pytest
@pytest.mark.number
def test_add():
    output=mathfile.add(2,3)
    assert output==5
@pytest.mark.number
def test_add_sub():
    output=mathfile.sub(4,3)
    assert output==1
@pytest.mark.number
def test_multiply():
    output=mathfile.multiply(2,3)
    assert output==6
@pytest.mark.string
def test_add1():
    output=mathfile.add('Hello',' world')
    assert output=='Hello world'
# Out:
# Overwriting test_mathfile1.py

# %%
# %%writefile test_multiple_level_testing_mathfile1.py

import mathfile
import pytest

def test_add():
    output=mathfile.add(2,3)
    assert output==5
    assert mathfile.add(2.5,6.5)==9.0
    assert mathfile.add('hello',' testing')=='hello testing'
# Out:
# Overwriting test_multiple_level_testing_mathfile1.py

# %%
# %%writefile test_multiple_level_testing_mathfile2.py

import mathfile
import pytest

@pytest.mark.parametrize('a,b,result',
                         [(5,6,11),
                           (2.5,6.5,9.0),
                           ("hello","testing","hellotesting")
                          ]
                        )
def test_add(a,b,result):
    assert mathfile.add(a,b) == result
# Out:
# Overwriting test_multiple_level_testing_mathfile2.py

# %%
# %%writefile conftest.py

import pytest
@pytest.fixture

def input_data():
    total=100
    return total
# Out:
# Writing conftest.py

# %%
# %%writefile test_logic.py

import pytest
def test_total_by_5(input_data):
    assert input_data %5==0
def test_total_by_10(input_data):
    assert input_data %10==0
# Out:
# Overwriting test_logic.py

# %%
def abc(a=2,b=2):
    return a+b

# %%
abc(a=6,b=89)
# Out:
# 95

# %%
abc(45,56)
# Out:
# 101

# %%
abc()
# Out:
# 4

# %%
def abc(*a):
    return sum(a)

# %%
abc(89,56,23,78,89,56,45)
# Out:
# 436

# %%
def abc(**a):
    return sum(a.values())

# %%
abc(x=78,b=89,c=56)
# Out:
# 223

# %%
def abc(a=2,b=2):
    return a+b

# %%
abc(78,b=45)
# Out:
# 123

# %%
x=5

# %%
x<0
# Out:
# False

# %%
x=int(input("enter a value"))
print(1<x<10)
print(x<10<x*10<100)
print(5==x>4)
print(10>x<=9)
# Out:
# enter a value5
# True
# True
# True
# True

# %% [raw]
# numpy
# pandas
# matplotlib
# seaborn
# dash
# sklearn
# opencv/cv2
# keras
# tensorflow
# spacy
# nltk
# gensim
# librosa
# pyspark

# %%
import numpy as np
import pandas as pd

# %%
a=np.array([45,56,89,56,56])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
b=[45,89,56,98,56]

# %%
type(b)
# Out:
# list

# %%
a/2
# Out:
# array([22.5, 28. , 44.5, 28. , 28. ])

# %%
b/2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-b756d9006b5d> in <module>
# ----> 1 b/2
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
a.ndim
# Out:
# 1

# %%
import pandas as pd

# %%
data={
    "Name":["ashish","harsh","jhon","mack","julee","ankit"],
    "Age":[32,45,56,33,30,47],
    "Gender":['male','male','male','male','female','male'],
    "Credit_Score":[784,458,652,785,525,652],
    "HasCrCard":["yes","no","yes","no","yes","yes"],
    "Salary":[4578,56895,568945,25564,56896,568925.25]
}

# %%
type(data)
# Out:
# dict

# %%
data=pd.DataFrame(data)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#      Name  Age  Gender  Credit_Score HasCrCard     Salary
# 0  ashish   32    male           784       yes    4578.00
# 1   harsh   45    male           458        no   56895.00
# 2    jhon   56    male           652       yes  568945.00
# 3    mack   33    male           785        no   25564.00
# 4   julee   30  female           525       yes   56896.00
# 5   ankit   47    male           652       yes  568925.25

# %%
data.shape
# Out:
# (6, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          6 non-null      object
#  1   Age           6 non-null      int64
#  2   Gender        6 non-null      object
#  3   Credit_Score  6 non-null      int64
#  4   HasCrCard     6 non-null      object
#  5   Salary        6 non-null      float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 416.0+ bytes

# %%
data.head()
# Out:
#      Name  Age  Gender  Credit_Score HasCrCard    Salary
# 0  ashish   32    male           784       yes    4578.0
# 1   harsh   45    male           458        no   56895.0
# 2    jhon   56    male           652       yes  568945.0
# 3    mack   33    male           785        no   25564.0
# 4   julee   30  female           525       yes   56896.0

# %%
data.tail()
# Out:
#     Name  Age  Gender  Credit_Score HasCrCard     Salary
# 1  harsh   45    male           458        no   56895.00
# 2   jhon   56    male           652       yes  568945.00
# 3   mack   33    male           785        no   25564.00
# 4  julee   30  female           525       yes   56896.00
# 5  ankit   47    male           652       yes  568925.25

# %%
data.head(2)
# Out:
#      Name  Age Gender  Credit_Score HasCrCard   Salary
# 0  ashish   32   male           784       yes   4578.0
# 1   harsh   45   male           458        no  56895.0

# %%
data.tail(3)
# Out:
#     Name  Age  Gender  Credit_Score HasCrCard     Salary
# 3   mack   33    male           785        no   25564.00
# 4  julee   30  female           525       yes   56896.00
# 5  ankit   47    male           652       yes  568925.25

# %%
data.size
# Out:
# 36

# %%
df=pd.read_csv(r"E:\\DataScience-data\\Bank_churn_modelling - Copy.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
df.tail(3)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
#selection
df['CreditScore']
# Out:
# 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64

# %%
df[['CreditScore',"Gender",'Age']]
# Out:
#       CreditScore  Gender  Age
# 0             619  Female   42
# 1             608  Female   41
# 2             502  Female   42
# 3             699  Female   39
# 4             850  Female   43
# ...           ...     ...  ...
# 9995          771    Male   39
# 9996          516    Male   35
# 9997          709  Female   36
# 9998          772    Male   42
# 9999          792  Female   28
#
# [10000 rows x 3 columns]

# %%
df[['CreditScore',"Gender",'Age']].head(10)
# Out:
#    CreditScore  Gender  Age
# 0          619  Female   42
# 1          608  Female   41
# 2          502  Female   42
# 3          699  Female   39
# 4          850  Female   43
# 5          645    Male   44
# 6          822    Male   50
# 7          376  Female   29
# 8          501    Male   44
# 9          684    Male   27

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df['Geography'].nunique()
# Out:
# 3

# %%
df['Age'].nunique()
# Out:
# 70

# %%
df['CustomerId'].nunique()
# Out:
# 10000

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([42, 41, 39, 43, 44, 50, 29, 27, 31, 24, 34, 25, 35, 45, 58, 32, 38,
#        46, 36, 33, 40, 51, 61, 49, 37, 19, 66, 56, 26, 21, 55, 75, 22, 30,
#        28, 65, 48, 52, 57, 73, 47, 54, 72, 20, 67, 79, 62, 53, 80, 59, 68,
#        23, 60, 70, 63, 64, 18, 82, 69, 74, 71, 76, 77, 88, 85, 84, 78, 81,
#        92, 83], dtype=int64)

# %%
df['Geography'].size
# Out:
# 10000

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.drop('Gender',axis=1,inplace=True)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Tenure    Balance  \
# 0          1    15634602  Hargrave          619    France       2       0.00
# 1          2    15647311      Hill          608     Spain       1   83807.86
# 2          3    15619304      Onio          502    France       8  159660.80
# 3          4    15701354      Boni          699    France       1       0.00
# 4          5    15737888  Mitchell          850     Spain       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %%
df.drop('RowNumber',axis=1,inplace=True)

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Tenure    Balance  \
# 0    15634602  Hargrave          619    France       2       0.00
# 1    15647311      Hill          608     Spain       1   83807.86
# 2    15619304      Onio          502    France       8  159660.80
# 3    15701354      Boni          699    France       1       0.00
# 4    15737888  Mitchell          850     Spain       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %%
df.drop(['CustomerId','Surname'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619    France       2       0.00              1          1
# 1          608     Spain       1   83807.86              1          0
# 2          502    France       8  159660.80              3          1
# 3          699    France       1       0.00              2          0
# 4          850     Spain       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
df.drop(0,axis=0,inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Tenure    Balance  NumOfProducts  HasCrCard  \
# 1          608     Spain       1   83807.86              1          0
# 2          502    France       8  159660.80              3          1
# 3          699    France       1       0.00              2          0
# 4          850     Spain       2  125510.82              1          1
# 5          645     Spain       8  113755.78              2          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0
# 5               0        149756.71       1

# %%
data=df.copy()

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# ...

# %%
df.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.loc[[1,2],:]
# Out:
#    RowNumber  CustomerId Surname  CreditScore Geography  Gender  Age  Tenure  \
# 1          2    15647311    Hill          608     Spain  Female   41       1
# 2          3    15619304    Onio          502    France  Female   42       8
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
#
#    Exited
# 1       0
# 2       1

# %%
data.loc[:,['CreditScore','Gender']]
# Out:
#       CreditScore  Gender
# 0             619  Female
# 1             608  Female
# 2             502  Female
# 3             699  Female
# 4             850  Female
# ...           ...     ...
# 9995          771    Male
# 9996          516    Male
# 9997          709  Female
# 9998          772    Male
# 9999          792  Female
#
# [10000 rows x 2 columns]

# %%
data.loc[[200,201],['CreditScore','Gender']]
# Out:
#      CreditScore Gender
# 200          850   Male
# 201          759   Male

# %%
data.iloc[:,3:7:2]
# Out:
#       CreditScore  Gender
# 0             619  Female
# 1             608  Female
# 2             502  Female
# 3             699  Female
# 4             850  Female
# ...           ...     ...
# 9995          771    Male
# 9996          516    Male
# 9997          709  Female
# 9998          772    Male
# 9999          792  Female
#
# [10000 rows x 2 columns]

# %%
data.iloc[200:202,3:7:2]
# Out:
#      CreditScore Gender
# 200          850   Male
# 201          759   Male

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data[data['Age']<50]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 16           17    15737452        Romeo          653   Germany    Male   58
# 41           42    15738148       Clarke          465    France  Female   51
# 42           43    15687946      Osborne          556    France  Female   61
# 44           45    15684171      Bianchi          660     Spain  Female   61
# 58           59    15623944        T'ien          511     Spain  Female   66
# ...         ...         ...          ...          ...       ...     ...  ...
# 9936       9937    15653037        Parks          609    France    Male   77
# 9939       9940    15808971       Lajoie          693     Spain  Female   57
# 9948       9949    15735078    Onwughara          724   Germany  Female   53
# 9979       9980    15692664       Diribe          677    France  Female   58
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
#
# ...

# %%
data[(data['Age'])>30 & (data['Age']<50)]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data[(data['Age']>30)&(data['Age']<50)]
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602     Hargrave          619    France  Female   42
# 1             2    15647311         Hill          608     Spain  Female   41
# 2             3    15619304         Onio          502    France  Female   42
# 3             4    15701354         Boni          699    France  Female   39
# 4             5    15737888     Mitchell          850     Spain  Female   43
# ...         ...         ...          ...          ...       ...     ...  ...
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9997       9998    15584532          Liu          709    France  Female   36
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
#
# ...

# %%
data['CreditScore'].describe()
# Out:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: CreditScore, dtype: float64

# %%
data['CreditScore'].mean()
# Out:
# 650.5288

# %%
data['CreditScore'].max()
# Out:
# 850

# %%
data['CreditScore'].count()
# Out:
# 10000

# %%
data['CreditScore'].min()
# Out:
# 350

# %%
data['CreditScore'].skew()
# Out:
# -0.07160660820092675

# %%
data['CreditScore'].var()
# Out:
# 9341.860156575705

# %%
data['CreditScore'].std()
# Out:
# 96.65329873613061

# %%
data[['Age','CreditScore']].cov()
# Out:
#                     Age  CreditScore
# Age          109.994084    -4.019150
# CreditScore   -4.019150  9341.860157

# %%
data[['Age','CreditScore']].corr()
# Out:
#                   Age  CreditScore
# Age          1.000000    -0.003965
# CreditScore -0.003965     1.000000

# %%
data['CreditScore'].quantile(0.25)
# Out:
# 584.0

# %%
data['CreditScore'].quantile(0.75)
# Out:
# 718.0

# %%
data['CreditScore'].quantile(0.50)
# Out:
# 652.0

# %%
data.shape[0]
# Out:
# 10000

# %%
data[(data['Gender']=='Female')&(data['CreditScore']<500)].shape[0]
# Out:
# 296

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.sort_values('CreditScore')

# %%
data.sort_values('CreditScore',ascending=False)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 792         793    15707473     Summers          850   Germany  Female   48
# 4083       4084    15672640  Kambinachi          850     Spain  Female   45
# 4158       4159    15771580     Davison          850    France  Female   38
# 4157       4158    15719793      Watson          850     Spain    Male   62
# 7413       7414    15604536      Vachon          850   Germany  Female   31
# ...         ...         ...         ...          ...       ...     ...  ...
# 8762       8763    15765173         Lin          350    France  Female   60
# 1631       1632    15685372    Azubuike          350     Spain    Male   54
# 9624       9625    15668309      Maslow          350    France  Female   40
# 1838       1839    15758813    Campbell          350   Germany    Male   39
# 8723       8724    15803202   Onyekachi          350    France    Male   51
#
# ...
